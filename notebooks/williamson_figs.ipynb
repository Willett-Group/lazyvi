# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(style="ticks", font_scale=1.75)

import pandas as pd
import numpy as np
from scipy import stats as st

import warnings
warnings.filterwarnings('ignore')

import sys, os
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from utils import *
from data_generating_funcs import *

# %%
# full experiment with retrain
df = pd.read_csv('../paper_simulations/results/williamson4_n1000_iter100_retrain.csv') 
df['hit'] = df.apply(lambda x: calculate_cvg(x.vi, x.se, x.true_vi), axis=1)
df['bias'] = df.true_vi - df.vi
df['half_width'] = df.

# %%
df.groupby(['varr', 'method']).mean()
# Out:
#                           vi        se      time  true_vi   hit      bias
# varr       method
# X1         lazy     0.137970  0.023687  0.605114    0.136  0.95 -0.001970
#            retrain  0.138242  0.023710  7.592198    0.136  0.96 -0.002242
# X2         lazy     0.239697  0.027318  0.601532    0.236  0.98 -0.003697
#            retrain  0.239939  0.027413  7.515259    0.236  0.97 -0.003939
# X3         lazy    -0.000152  0.005689  0.620362    0.000  0.99  0.000152
#            retrain -0.001848  0.007155  7.456890    0.000  0.96  0.001848
# X4         lazy    -0.002455  0.005457  0.626330    0.000  0.97  0.002455
#            retrain -0.002061  0.007020  7.533870    0.000  0.96  0.002061
# full_model full     0.923848  0.000000       NaN      NaN  0.00       NaN
