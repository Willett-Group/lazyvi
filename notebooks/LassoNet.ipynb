# %%
from functools import partial

import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score


from lassonet import LassoNetRegressor, plot_path


def linear():
    p = 10
    n = 400
    coef = np.concatenate([np.random.choice([-1, 1], size=p), [0] * p])
    X = np.random.randn(n, 2 * p)

    linear = X.dot(coef)
    noise = np.random.randn(n)

    y = linear + noise
    return X, y


def strong_linear():
    p = 10
    n = 400
    coef = np.concatenate([np.random.choice([-1, 1], size=p), [0] * p])
    X = np.random.randn(n, 2 * p)

    linear = X.dot(coef)
    noise = np.random.randn(n)
    x1, x2, x3, *_ = X.T
    nonlinear = 2 * (x1 ** 3 - 3 * x1) + 4 * (x2 ** 2 * x3 - x3)
    y = 6 * linear + 8 * noise + nonlinear
    return X, y


def friedman_lockout():
    p = 200
    n = 1000
    X = np.random.rand(n, p)
    y = (
        10 * np.sin(np.pi * X[:, 0] * X[:, 1])
        + 20 * (X[:, 2] - 0.5) ** 2
        + 10 * X[:, 3]
        + 5 * X[:, 4]
    )
    return X, y


for generator in [linear, strong_linear, friedman_lockout]:
    X, y = generator()
    X = StandardScaler().fit_transform(X)
    y -= y.mean()
    y /= y.std()
    X_train, X_test, y_train, y_test = train_test_split(X, y)

    model = LassoNetRegressor(verbose=True, path_multiplier=1.01, hidden_dims=(10, 10))

    path = model.path(X_train, y_train)
    import matplotlib.pyplot as plt

    def score(self, X, y, sample_weight=None):
        y_pred = self.predict(X)
        return np.sqrt(1 - r2_score(y, y_pred, sample_weight=sample_weight))

    model.score = partial(score, model)

    plot_path(model, path, X_test, y_test)
    plt.show()
# Out:
# Initialized dense model in 451 epochs, val loss 1.63e-01, regularization 1.92e+00
# Lambda = 1.63e-01, selected 20 features in 10 epochs
# val_objective 4.83e-01, val_loss 1.67e-01, regularization 1.95e+00
# Lambda = 1.64e-01, selected 20 features in 10 epochs
# val_objective 4.82e-01, val_loss 1.66e-01, regularization 1.93e+00
# Lambda = 1.66e-01, selected 20 features in 10 epochs
# val_objective 4.81e-01, val_loss 1.65e-01, regularization 1.91e+00
# Lambda = 1.68e-01, selected 20 features in 10 epochs
# val_objective 4.81e-01, val_loss 1.64e-01, regularization 1.89e+00
# Lambda = 1.69e-01, selected 20 features in 10 epochs
# val_objective 4.82e-01, val_loss 1.63e-01, regularization 1.88e+00
# Lambda = 1.71e-01, selected 20 features in 10 epochs
# val_objective 4.82e-01, val_loss 1.62e-01, regularization 1.87e+00
# Lambda = 1.73e-01, selected 20 features in 10 epochs
# val_objective 4.83e-01, val_loss 1.62e-01, regularization 1.86e+00
# Lambda = 1.74e-01, selected 20 features in 10 epochs
# val_objective 4.85e-01, val_loss 1.62e-01, regularization 1.85e+00
# Lambda = 1.76e-01, selected 20 features in 10 epochs
# val_objective 4.86e-01, val_loss 1.61e-01, regularization 1.84e+00
# Lambda = 1.78e-01, selected 20 features in 10 epochs
# val_objective 4.87e-01, val_loss 1.61e-01, regularization 1.83e+00
# Lambda = 1.80e-01, selected 20 features in 10 epochs
# val_objective 4.88e-01, val_loss 1.61e-01, regularization 1.82e+00
# Lambda = 1.81e-01, selected 20 features in 10 epochs
# val_objective 4.89e-01, val_loss 1.60e-01, regularization 1.81e+00
# Lambda = 1.83e-01, selected 20 features in 10 epochs
# val_objective 4.91e-01, val_loss 1.60e-01, regularization 1.81e+00
# Lambda = 1.85e-01, selected 20 features in 10 epochs
# val_objective 4.92e-01, val_loss 1.60e-01, regularization 1.80e+00
# Lambda = 1.87e-01, selected 20 features in 10 epochs
# val_objective 4.94e-01, val_loss 1.60e-01, regularization 1.79e+00
# Lambda = 1.89e-01, selected 20 features in 10 epochs
# val_objective 4.95e-01, val_loss 1.59e-01, regularization 1.78e+00
# Lambda = 1.91e-01, selected 20 features in 10 epochs
# val_objective 4.97e-01, val_loss 1.59e-01, regularization 1.77e+00
# Lambda = 1.93e-01, selected 20 features in 10 epochs
# val_objective 4.98e-01, val_loss 1.59e-01, regularization 1.76e+00
# Lambda = 1.94e-01, selected 20 features in 10 epochs
# val_objective 5.00e-01, val_loss 1.59e-01, regularization 1.75e+00
# Lambda = 1.96e-01, selected 20 features in 10 epochs
# val_objective 5.01e-01, val_loss 1.58e-01, regularization 1.74e+00
# Lambda = 1.98e-01, selected 20 features in 10 epochs
# val_objective 5.02e-01, val_loss 1.58e-01, regularization 1.74e+00
# Lambda = 2.00e-01, selected 20 features in 10 epochs
# val_objective 5.04e-01, val_loss 1.58e-01, regularization 1.73e+00
# Lambda = 2.02e-01, selected 20 features in 10 epochs
# val_objective 5.05e-01, val_loss 1.58e-01, regularization 1.72e+00
# Lambda = 2.04e-01, selected 20 features in 10 epochs
# val_objective 5.06e-01, val_loss 1.57e-01, regularization 1.71e+00
# Lambda = 2.06e-01, selected 20 features in 10 epochs
# val_objective 5.08e-01, val_loss 1.57e-01, regularization 1.70e+00
# Lambda = 2.09e-01, selected 20 features in 10 epochs
# val_objective 5.09e-01, val_loss 1.57e-01, regularization 1.69e+00
# Lambda = 2.11e-01, selected 20 features in 10 epochs
# val_objective 5.10e-01, val_loss 1.56e-01, regularization 1.68e+00
# Lambda = 2.13e-01, selected 20 features in 10 epochs
# val_objective 5.11e-01, val_loss 1.56e-01, regularization 1.67e+00
# Lambda = 2.15e-01, selected 20 features in 10 epochs
# val_objective 5.13e-01, val_loss 1.56e-01, regularization 1.66e+00
# Lambda = 2.17e-01, selected 20 features in 10 epochs
# val_objective 5.14e-01, val_loss 1.56e-01, regularization 1.65e+00
# Lambda = 2.19e-01, selected 20 features in 10 epochs
# val_objective 5.15e-01, val_loss 1.55e-01, regularization 1.64e+00
# Lambda = 2.21e-01, selected 20 features in 10 epochs
# val_objective 5.16e-01, val_loss 1.55e-01, regularization 1.63e+00
# Lambda = 2.24e-01, selected 20 features in 10 epochs
# val_objective 5.18e-01, val_loss 1.55e-01, regularization 1.62e+00
# Lambda = 2.26e-01, selected 20 features in 10 epochs
# val_objective 5.19e-01, val_loss 1.55e-01, regularization 1.61e+00
# Lambda = 2.28e-01, selected 20 features in 10 epochs
# val_objective 5.21e-01, val_loss 1.55e-01, regularization 1.61e+00
# Lambda = 2.30e-01, selected 20 features in 10 epochs
# val_objective 5.22e-01, val_loss 1.54e-01, regularization 1.60e+00
# Lambda = 2.33e-01, selected 20 features in 10 epochs
# val_objective 5.23e-01, val_loss 1.54e-01, regularization 1.59e+00
# Lambda = 2.35e-01, selected 20 features in 10 epochs
# val_objective 5.25e-01, val_loss 1.54e-01, regularization 1.58e+00
# Lambda = 2.37e-01, selected 20 features in 10 epochs
# val_objective 5.26e-01, val_loss 1.54e-01, regularization 1.57e+00
# Lambda = 2.40e-01, selected 20 features in 10 epochs
# val_objective 5.27e-01, val_loss 1.53e-01, regularization 1.56e+00
# Lambda = 2.42e-01, selected 20 features in 10 epochs
# val_objective 5.29e-01, val_loss 1.53e-01, regularization 1.55e+00
# Lambda = 2.44e-01, selected 20 features in 10 epochs
# val_objective 5.30e-01, val_loss 1.53e-01, regularization 1.54e+00
# Lambda = 2.47e-01, selected 20 features in 10 epochs
# val_objective 5.31e-01, val_loss 1.53e-01, regularization 1.53e+00
# Lambda = 2.49e-01, selected 20 features in 10 epochs
# val_objective 5.33e-01, val_loss 1.53e-01, regularization 1.52e+00
# Lambda = 2.52e-01, selected 20 features in 10 epochs
# val_objective 5.34e-01, val_loss 1.52e-01, regularization 1.51e+00
# Lambda = 2.54e-01, selected 20 features in 10 epochs
# val_objective 5.35e-01, val_loss 1.52e-01, regularization 1.51e+00
# Lambda = 2.57e-01, selected 20 features in 10 epochs
# val_objective 5.36e-01, val_loss 1.52e-01, regularization 1.50e+00
# Lambda = 2.60e-01, selected 20 features in 10 epochs
# val_objective 5.37e-01, val_loss 1.52e-01, regularization 1.49e+00
# Lambda = 2.62e-01, selected 20 features in 10 epochs
# val_objective 5.39e-01, val_loss 1.51e-01, regularization 1.48e+00
# Lambda = 2.65e-01, selected 20 features in 10 epochs
# val_objective 5.40e-01, val_loss 1.51e-01, regularization 1.47e+00
# Lambda = 2.67e-01, selected 20 features in 10 epochs
# val_objective 5.41e-01, val_loss 1.51e-01, regularization 1.46e+00
# Lambda = 2.70e-01, selected 20 features in 10 epochs
# val_objective 5.42e-01, val_loss 1.51e-01, regularization 1.45e+00
# Lambda = 2.73e-01, selected 20 features in 10 epochs
# val_objective 5.43e-01, val_loss 1.50e-01, regularization 1.44e+00
# Lambda = 2.75e-01, selected 20 features in 10 epochs
# val_objective 5.43e-01, val_loss 1.50e-01, regularization 1.43e+00
# Lambda = 2.78e-01, selected 20 features in 10 epochs
# val_objective 5.44e-01, val_loss 1.50e-01, regularization 1.42e+00
# Lambda = 2.81e-01, selected 20 features in 10 epochs
# val_objective 5.46e-01, val_loss 1.50e-01, regularization 1.41e+00
# Lambda = 2.84e-01, selected 20 features in 10 epochs
# val_objective 5.47e-01, val_loss 1.50e-01, regularization 1.40e+00
# Lambda = 2.87e-01, selected 20 features in 10 epochs
# val_objective 5.49e-01, val_loss 1.50e-01, regularization 1.39e+00
# Lambda = 2.90e-01, selected 20 features in 10 epochs
# val_objective 5.50e-01, val_loss 1.50e-01, regularization 1.38e+00
# Lambda = 2.92e-01, selected 20 features in 10 epochs
# val_objective 5.52e-01, val_loss 1.50e-01, regularization 1.37e+00
# Lambda = 2.95e-01, selected 20 features in 10 epochs
# val_objective 5.53e-01, val_loss 1.50e-01, regularization 1.37e+00
# Lambda = 2.98e-01, selected 20 features in 10 epochs
# val_objective 5.55e-01, val_loss 1.50e-01, regularization 1.36e+00
# Lambda = 3.01e-01, selected 20 features in 10 epochs
# val_objective 5.56e-01, val_loss 1.50e-01, regularization 1.35e+00
# Lambda = 3.04e-01, selected 20 features in 10 epochs
# val_objective 5.58e-01, val_loss 1.50e-01, regularization 1.34e+00
# Lambda = 3.07e-01, selected 20 features in 10 epochs
# val_objective 5.59e-01, val_loss 1.50e-01, regularization 1.33e+00
# Lambda = 3.10e-01, selected 20 features in 10 epochs
# val_objective 5.60e-01, val_loss 1.50e-01, regularization 1.32e+00
# Lambda = 3.14e-01, selected 20 features in 10 epochs
# val_objective 5.62e-01, val_loss 1.50e-01, regularization 1.31e+00
# Lambda = 3.17e-01, selected 20 features in 10 epochs
# val_objective 5.63e-01, val_loss 1.50e-01, regularization 1.30e+00
# Lambda = 3.20e-01, selected 20 features in 10 epochs
# val_objective 5.64e-01, val_loss 1.50e-01, regularization 1.30e+00
# Lambda = 3.23e-01, selected 20 features in 10 epochs
# val_objective 5.65e-01, val_loss 1.50e-01, regularization 1.29e+00
# Lambda = 3.26e-01, selected 20 features in 10 epochs
# val_objective 5.66e-01, val_loss 1.50e-01, regularization 1.28e+00
# Lambda = 3.30e-01, selected 20 features in 10 epochs
# val_objective 5.67e-01, val_loss 1.50e-01, regularization 1.27e+00
# Lambda = 3.33e-01, selected 20 features in 10 epochs
# val_objective 5.68e-01, val_loss 1.50e-01, regularization 1.26e+00
# Lambda = 3.36e-01, selected 20 features in 10 epochs
# val_objective 5.69e-01, val_loss 1.50e-01, regularization 1.25e+00
# Lambda = 3.40e-01, selected 20 features in 10 epochs
# val_objective 5.70e-01, val_loss 1.50e-01, regularization 1.24e+00
# Lambda = 3.43e-01, selected 20 features in 10 epochs
# val_objective 5.71e-01, val_loss 1.50e-01, regularization 1.23e+00
# Lambda = 3.46e-01, selected 20 features in 10 epochs
# val_objective 5.72e-01, val_loss 1.49e-01, regularization 1.22e+00
# Lambda = 3.50e-01, selected 20 features in 10 epochs
# val_objective 5.73e-01, val_loss 1.49e-01, regularization 1.21e+00
# Lambda = 3.53e-01, selected 20 features in 10 epochs
# val_objective 5.73e-01, val_loss 1.49e-01, regularization 1.20e+00
# Lambda = 3.57e-01, selected 20 features in 10 epochs
# val_objective 5.74e-01, val_loss 1.49e-01, regularization 1.19e+00
# Lambda = 3.60e-01, selected 20 features in 10 epochs
# val_objective 5.74e-01, val_loss 1.49e-01, regularization 1.18e+00
# Lambda = 3.64e-01, selected 20 features in 10 epochs
# val_objective 5.75e-01, val_loss 1.49e-01, regularization 1.17e+00
# Lambda = 3.68e-01, selected 20 features in 10 epochs
# val_objective 5.75e-01, val_loss 1.49e-01, regularization 1.16e+00
# Lambda = 3.71e-01, selected 20 features in 10 epochs
# val_objective 5.76e-01, val_loss 1.48e-01, regularization 1.15e+00
# Lambda = 3.75e-01, selected 20 features in 10 epochs
# val_objective 5.76e-01, val_loss 1.48e-01, regularization 1.14e+00
# Lambda = 3.79e-01, selected 20 features in 10 epochs
# val_objective 5.76e-01, val_loss 1.48e-01, regularization 1.13e+00
# Lambda = 3.83e-01, selected 20 features in 10 epochs
# val_objective 5.76e-01, val_loss 1.47e-01, regularization 1.12e+00
# Lambda = 3.86e-01, selected 20 features in 10 epochs
# val_objective 5.76e-01, val_loss 1.47e-01, regularization 1.11e+00
# Lambda = 3.90e-01, selected 20 features in 10 epochs
# val_objective 5.77e-01, val_loss 1.47e-01, regularization 1.10e+00
# Lambda = 3.94e-01, selected 20 features in 10 epochs
# val_objective 5.78e-01, val_loss 1.47e-01, regularization 1.09e+00
# Lambda = 3.98e-01, selected 20 features in 10 epochs
# val_objective 5.78e-01, val_loss 1.47e-01, regularization 1.08e+00
# Lambda = 4.02e-01, selected 20 features in 10 epochs
# val_objective 5.79e-01, val_loss 1.46e-01, regularization 1.08e+00
# Lambda = 4.06e-01, selected 20 features in 10 epochs
# val_objective 5.80e-01, val_loss 1.46e-01, regularization 1.07e+00
# Lambda = 4.10e-01, selected 20 features in 10 epochs
# val_objective 5.80e-01, val_loss 1.46e-01, regularization 1.06e+00
# Lambda = 4.14e-01, selected 20 features in 10 epochs
# val_objective 5.81e-01, val_loss 1.46e-01, regularization 1.05e+00
# Lambda = 4.18e-01, selected 20 features in 10 epochs
# val_objective 5.81e-01, val_loss 1.46e-01, regularization 1.04e+00
# Lambda = 4.23e-01, selected 20 features in 10 epochs
# val_objective 5.82e-01, val_loss 1.46e-01, regularization 1.03e+00
# Lambda = 4.27e-01, selected 20 features in 10 epochs
# val_objective 5.83e-01, val_loss 1.46e-01, regularization 1.02e+00
# Lambda = 4.31e-01, selected 20 features in 10 epochs
# val_objective 5.84e-01, val_loss 1.46e-01, regularization 1.02e+00
# Lambda = 4.35e-01, selected 20 features in 10 epochs
# val_objective 5.85e-01, val_loss 1.46e-01, regularization 1.01e+00
# Lambda = 4.40e-01, selected 20 features in 10 epochs
# val_objective 5.85e-01, val_loss 1.46e-01, regularization 1.00e+00
# Lambda = 4.44e-01, selected 20 features in 10 epochs
# val_objective 5.86e-01, val_loss 1.46e-01, regularization 9.92e-01
# Lambda = 4.49e-01, selected 20 features in 10 epochs
# val_objective 5.87e-01, val_loss 1.45e-01, regularization 9.84e-01
# Lambda = 4.53e-01, selected 20 features in 10 epochs
# val_objective 5.88e-01, val_loss 1.45e-01, regularization 9.76e-01
# Lambda = 4.58e-01, selected 20 features in 10 epochs
# val_objective 5.88e-01, val_loss 1.45e-01, regularization 9.69e-01
# Lambda = 4.62e-01, selected 20 features in 10 epochs
# val_objective 5.89e-01, val_loss 1.45e-01, regularization 9.61e-01
# Lambda = 4.67e-01, selected 20 features in 10 epochs
# val_objective 5.90e-01, val_loss 1.45e-01, regularization 9.55e-01
# Lambda = 4.71e-01, selected 20 features in 10 epochs
# val_objective 5.91e-01, val_loss 1.44e-01, regularization 9.48e-01
# Lambda = 4.76e-01, selected 20 features in 10 epochs
# val_objective 5.92e-01, val_loss 1.44e-01, regularization 9.42e-01
# Lambda = 4.81e-01, selected 20 features in 10 epochs
# val_objective 5.93e-01, val_loss 1.44e-01, regularization 9.35e-01
# Lambda = 4.86e-01, selected 20 features in 10 epochs
# val_objective 5.95e-01, val_loss 1.43e-01, regularization 9.30e-01
# Lambda = 4.91e-01, selected 20 features in 10 epochs
# val_objective 5.97e-01, val_loss 1.43e-01, regularization 9.24e-01
# Lambda = 4.96e-01, selected 20 features in 10 epochs
# val_objective 5.99e-01, val_loss 1.43e-01, regularization 9.19e-01
# Lambda = 5.00e-01, selected 20 features in 10 epochs
# val_objective 6.00e-01, val_loss 1.43e-01, regularization 9.14e-01
# Lambda = 5.05e-01, selected 20 features in 10 epochs
# val_objective 6.02e-01, val_loss 1.43e-01, regularization 9.09e-01
# Lambda = 5.11e-01, selected 20 features in 10 epochs
# val_objective 6.04e-01, val_loss 1.43e-01, regularization 9.04e-01
# Lambda = 5.16e-01, selected 20 features in 10 epochs
# val_objective 6.06e-01, val_loss 1.42e-01, regularization 8.98e-01
# Lambda = 5.21e-01, selected 20 features in 10 epochs
# val_objective 6.07e-01, val_loss 1.42e-01, regularization 8.93e-01
# Lambda = 5.26e-01, selected 20 features in 10 epochs
# val_objective 6.09e-01, val_loss 1.42e-01, regularization 8.88e-01
# Lambda = 5.31e-01, selected 20 features in 10 epochs
# val_objective 6.11e-01, val_loss 1.42e-01, regularization 8.82e-01
# Lambda = 5.37e-01, selected 20 features in 10 epochs
# val_objective 6.13e-01, val_loss 1.42e-01, regularization 8.78e-01
# Lambda = 5.42e-01, selected 20 features in 10 epochs
# val_objective 6.16e-01, val_loss 1.42e-01, regularization 8.74e-01
# Lambda = 5.47e-01, selected 20 features in 10 epochs
# val_objective 6.18e-01, val_loss 1.42e-01, regularization 8.70e-01
# Lambda = 5.53e-01, selected 20 features in 10 epochs
# val_objective 6.21e-01, val_loss 1.42e-01, regularization 8.66e-01
# Lambda = 5.58e-01, selected 20 features in 10 epochs
# val_objective 6.24e-01, val_loss 1.42e-01, regularization 8.63e-01
# Lambda = 5.64e-01, selected 20 features in 10 epochs
# val_objective 6.26e-01, val_loss 1.42e-01, regularization 8.59e-01
# Lambda = 5.70e-01, selected 20 features in 10 epochs
# val_objective 6.29e-01, val_loss 1.42e-01, regularization 8.55e-01
# Lambda = 5.75e-01, selected 20 features in 10 epochs
# val_objective 6.32e-01, val_loss 1.42e-01, regularization 8.51e-01
# Lambda = 5.81e-01, selected 20 features in 10 epochs
# val_objective 6.34e-01, val_loss 1.42e-01, regularization 8.47e-01
# Lambda = 5.87e-01, selected 20 features in 10 epochs
# val_objective 6.37e-01, val_loss 1.42e-01, regularization 8.43e-01
# Lambda = 5.93e-01, selected 20 features in 10 epochs
# val_objective 6.39e-01, val_loss 1.42e-01, regularization 8.39e-01
# Lambda = 5.99e-01, selected 20 features in 10 epochs
# val_objective 6.42e-01, val_loss 1.42e-01, regularization 8.35e-01
# Lambda = 6.05e-01, selected 20 features in 10 epochs
# val_objective 6.45e-01, val_loss 1.42e-01, regularization 8.31e-01
# Lambda = 6.11e-01, selected 20 features in 10 epochs
# val_objective 6.47e-01, val_loss 1.42e-01, regularization 8.27e-01
# Lambda = 6.17e-01, selected 20 features in 10 epochs
# val_objective 6.50e-01, val_loss 1.42e-01, regularization 8.23e-01
# Lambda = 6.23e-01, selected 20 features in 10 epochs
# val_objective 6.52e-01, val_loss 1.42e-01, regularization 8.19e-01
# Lambda = 6.29e-01, selected 20 features in 10 epochs
# val_objective 6.54e-01, val_loss 1.42e-01, regularization 8.14e-01
# Lambda = 6.35e-01, selected 20 features in 10 epochs
# val_objective 6.57e-01, val_loss 1.42e-01, regularization 8.10e-01
# Lambda = 6.42e-01, selected 20 features in 10 epochs
# val_objective 6.59e-01, val_loss 1.42e-01, regularization 8.05e-01
# Lambda = 6.48e-01, selected 20 features in 10 epochs
# val_objective 6.62e-01, val_loss 1.42e-01, regularization 8.01e-01
# Lambda = 6.55e-01, selected 20 features in 10 epochs
# val_objective 6.64e-01, val_loss 1.43e-01, regularization 7.96e-01
# Lambda = 6.61e-01, selected 20 features in 10 epochs
# val_objective 6.66e-01, val_loss 1.43e-01, regularization 7.92e-01
# Lambda = 6.68e-01, selected 20 features in 10 epochs
# val_objective 6.69e-01, val_loss 1.43e-01, regularization 7.87e-01
# Lambda = 6.75e-01, selected 20 features in 10 epochs
# val_objective 6.71e-01, val_loss 1.43e-01, regularization 7.83e-01
# Lambda = 6.81e-01, selected 20 features in 10 epochs
# val_objective 6.73e-01, val_loss 1.43e-01, regularization 7.78e-01
# Lambda = 6.88e-01, selected 20 features in 10 epochs
# val_objective 6.75e-01, val_loss 1.43e-01, regularization 7.73e-01
# Lambda = 6.95e-01, selected 20 features in 10 epochs
# val_objective 6.77e-01, val_loss 1.43e-01, regularization 7.68e-01
# Lambda = 7.02e-01, selected 20 features in 10 epochs
# val_objective 6.79e-01, val_loss 1.43e-01, regularization 7.63e-01
# Lambda = 7.09e-01, selected 20 features in 10 epochs
# val_objective 6.81e-01, val_loss 1.43e-01, regularization 7.58e-01
# Lambda = 7.16e-01, selected 20 features in 10 epochs
# val_objective 6.83e-01, val_loss 1.44e-01, regularization 7.53e-01
# Lambda = 7.23e-01, selected 20 features in 10 epochs
# val_objective 6.85e-01, val_loss 1.44e-01, regularization 7.48e-01
# Lambda = 7.30e-01, selected 20 features in 10 epochs
# val_objective 6.87e-01, val_loss 1.44e-01, regularization 7.43e-01
# Lambda = 7.38e-01, selected 20 features in 10 epochs
# val_objective 6.88e-01, val_loss 1.44e-01, regularization 7.38e-01
# Lambda = 7.45e-01, selected 20 features in 10 epochs
# val_objective 6.90e-01, val_loss 1.44e-01, regularization 7.33e-01
# Lambda = 7.53e-01, selected 20 features in 10 epochs
# val_objective 6.92e-01, val_loss 1.44e-01, regularization 7.27e-01
# Lambda = 7.60e-01, selected 20 features in 10 epochs
# val_objective 6.96e-01, val_loss 1.45e-01, regularization 7.25e-01
# Lambda = 7.68e-01, selected 20 features in 10 epochs
# val_objective 6.99e-01, val_loss 1.45e-01, regularization 7.22e-01
# Lambda = 7.75e-01, selected 20 features in 10 epochs
# val_objective 7.03e-01, val_loss 1.46e-01, regularization 7.19e-01
# Lambda = 7.83e-01, selected 20 features in 10 epochs
# val_objective 7.07e-01, val_loss 1.46e-01, regularization 7.16e-01
# Lambda = 7.91e-01, selected 20 features in 10 epochs
# val_objective 7.10e-01, val_loss 1.46e-01, regularization 7.13e-01
# Lambda = 7.99e-01, selected 20 features in 10 epochs
# val_objective 7.14e-01, val_loss 1.46e-01, regularization 7.10e-01
# Lambda = 8.07e-01, selected 20 features in 10 epochs
# val_objective 7.17e-01, val_loss 1.47e-01, regularization 7.07e-01
# Lambda = 8.15e-01, selected 20 features in 10 epochs
# val_objective 7.20e-01, val_loss 1.47e-01, regularization 7.04e-01
# Lambda = 8.23e-01, selected 20 features in 10 epochs
# val_objective 7.24e-01, val_loss 1.47e-01, regularization 7.01e-01
# Lambda = 8.31e-01, selected 20 features in 10 epochs
# val_objective 7.27e-01, val_loss 1.47e-01, regularization 6.98e-01
# Lambda = 8.40e-01, selected 20 features in 10 epochs
# val_objective 7.31e-01, val_loss 1.47e-01, regularization 6.95e-01
# Lambda = 8.48e-01, selected 20 features in 10 epochs
# val_objective 7.34e-01, val_loss 1.48e-01, regularization 6.92e-01
# Lambda = 8.57e-01, selected 20 features in 10 epochs
# val_objective 7.38e-01, val_loss 1.48e-01, regularization 6.89e-01
# Lambda = 8.65e-01, selected 20 features in 10 epochs
# val_objective 7.41e-01, val_loss 1.48e-01, regularization 6.86e-01
# Lambda = 8.74e-01, selected 20 features in 10 epochs
# val_objective 7.44e-01, val_loss 1.48e-01, regularization 6.82e-01
# Lambda = 8.82e-01, selected 20 features in 10 epochs
# val_objective 7.48e-01, val_loss 1.48e-01, regularization 6.79e-01
# Lambda = 8.91e-01, selected 20 features in 10 epochs
# val_objective 7.51e-01, val_loss 1.48e-01, regularization 6.76e-01
# Lambda = 9.00e-01, selected 20 features in 10 epochs
# val_objective 7.54e-01, val_loss 1.49e-01, regularization 6.73e-01
# Lambda = 9.09e-01, selected 20 features in 10 epochs
# val_objective 7.58e-01, val_loss 1.49e-01, regularization 6.69e-01
# Lambda = 9.18e-01, selected 20 features in 10 epochs
# val_objective 7.61e-01, val_loss 1.49e-01, regularization 6.66e-01
# Lambda = 9.28e-01, selected 20 features in 10 epochs
# val_objective 7.64e-01, val_loss 1.49e-01, regularization 6.63e-01
# Lambda = 9.37e-01, selected 20 features in 10 epochs
# val_objective 7.67e-01, val_loss 1.49e-01, regularization 6.59e-01
# Lambda = 9.46e-01, selected 20 features in 10 epochs
# val_objective 7.70e-01, val_loss 1.50e-01, regularization 6.56e-01
# Lambda = 9.56e-01, selected 20 features in 10 epochs
# val_objective 7.73e-01, val_loss 1.50e-01, regularization 6.53e-01
# Lambda = 9.65e-01, selected 20 features in 10 epochs
# val_objective 7.77e-01, val_loss 1.50e-01, regularization 6.49e-01
# Lambda = 9.75e-01, selected 20 features in 10 epochs
# val_objective 7.80e-01, val_loss 1.50e-01, regularization 6.46e-01
# Lambda = 9.85e-01, selected 20 features in 10 epochs
# val_objective 7.83e-01, val_loss 1.51e-01, regularization 6.42e-01
# Lambda = 9.94e-01, selected 20 features in 10 epochs
# val_objective 7.86e-01, val_loss 1.51e-01, regularization 6.38e-01
# Lambda = 1.00e+00, selected 20 features in 10 epochs
# val_objective 7.89e-01, val_loss 1.51e-01, regularization 6.35e-01
# Lambda = 1.01e+00, selected 20 features in 10 epochs
# val_objective 7.92e-01, val_loss 1.51e-01, regularization 6.31e-01
# Lambda = 1.02e+00, selected 20 features in 10 epochs
# val_objective 7.94e-01, val_loss 1.52e-01, regularization 6.27e-01
# Lambda = 1.03e+00, selected 20 features in 10 epochs
# val_objective 7.97e-01, val_loss 1.52e-01, regularization 6.24e-01
# Lambda = 1.05e+00, selected 20 features in 10 epochs
# val_objective 8.00e-01, val_loss 1.52e-01, regularization 6.20e-01
# Lambda = 1.06e+00, selected 20 features in 10 epochs
# val_objective 8.02e-01, val_loss 1.53e-01, regularization 6.16e-01
# Lambda = 1.07e+00, selected 20 features in 10 epochs
# val_objective 8.05e-01, val_loss 1.53e-01, regularization 6.12e-01
# Lambda = 1.08e+00, selected 20 features in 10 epochs
# val_objective 8.10e-01, val_loss 1.53e-01, regularization 6.10e-01
# Lambda = 1.09e+00, selected 20 features in 10 epochs
# val_objective 8.15e-01, val_loss 1.52e-01, regularization 6.09e-01
# Lambda = 1.10e+00, selected 20 features in 10 epochs
# val_objective 8.20e-01, val_loss 1.52e-01, regularization 6.08e-01
# Lambda = 1.11e+00, selected 20 features in 10 epochs
# val_objective 8.26e-01, val_loss 1.52e-01, regularization 6.07e-01
# Lambda = 1.12e+00, selected 20 features in 10 epochs
# val_objective 8.31e-01, val_loss 1.52e-01, regularization 6.06e-01
# Lambda = 1.13e+00, selected 20 features in 10 epochs
# val_objective 8.37e-01, val_loss 1.52e-01, regularization 6.05e-01
# Lambda = 1.14e+00, selected 20 features in 10 epochs
# val_objective 8.42e-01, val_loss 1.52e-01, regularization 6.04e-01
# Lambda = 1.15e+00, selected 20 features in 10 epochs
# val_objective 8.48e-01, val_loss 1.52e-01, regularization 6.03e-01
# Lambda = 1.17e+00, selected 20 features in 10 epochs
# val_objective 8.53e-01, val_loss 1.52e-01, regularization 6.02e-01
# Lambda = 1.18e+00, selected 20 features in 10 epochs
# val_objective 8.59e-01, val_loss 1.52e-01, regularization 6.01e-01
# Lambda = 1.19e+00, selected 20 features in 10 epochs
# val_objective 8.65e-01, val_loss 1.52e-01, regularization 6.00e-01
# Lambda = 1.20e+00, selected 20 features in 10 epochs
# val_objective 8.71e-01, val_loss 1.52e-01, regularization 5.99e-01
# Lambda = 1.21e+00, selected 20 features in 10 epochs
# val_objective 8.77e-01, val_loss 1.52e-01, regularization 5.98e-01
# Lambda = 1.23e+00, selected 20 features in 10 epochs
# val_objective 8.83e-01, val_loss 1.52e-01, regularization 5.96e-01
# Lambda = 1.24e+00, selected 20 features in 10 epochs
# val_objective 8.88e-01, val_loss 1.51e-01, regularization 5.95e-01
# Lambda = 1.25e+00, selected 20 features in 10 epochs
# val_objective 8.94e-01, val_loss 1.51e-01, regularization 5.94e-01
# Lambda = 1.26e+00, selected 20 features in 10 epochs
# val_objective 9.00e-01, val_loss 1.51e-01, regularization 5.93e-01
# Lambda = 1.28e+00, selected 20 features in 10 epochs
# val_objective 9.06e-01, val_loss 1.51e-01, regularization 5.92e-01
# Lambda = 1.29e+00, selected 20 features in 10 epochs
# val_objective 9.13e-01, val_loss 1.51e-01, regularization 5.91e-01
# Lambda = 1.30e+00, selected 20 features in 10 epochs
# val_objective 9.19e-01, val_loss 1.51e-01, regularization 5.90e-01
# Lambda = 1.31e+00, selected 20 features in 10 epochs
# val_objective 9.25e-01, val_loss 1.51e-01, regularization 5.89e-01
# Lambda = 1.33e+00, selected 20 features in 10 epochs
# val_objective 9.31e-01, val_loss 1.51e-01, regularization 5.88e-01
# Lambda = 1.34e+00, selected 20 features in 10 epochs
# val_objective 9.37e-01, val_loss 1.51e-01, regularization 5.86e-01
# Lambda = 1.35e+00, selected 20 features in 10 epochs
# val_objective 9.44e-01, val_loss 1.51e-01, regularization 5.85e-01
# Lambda = 1.37e+00, selected 20 features in 10 epochs
# val_objective 9.50e-01, val_loss 1.51e-01, regularization 5.84e-01
# Lambda = 1.38e+00, selected 20 features in 10 epochs
# val_objective 9.56e-01, val_loss 1.51e-01, regularization 5.83e-01
# Lambda = 1.39e+00, selected 20 features in 10 epochs
# val_objective 9.63e-01, val_loss 1.51e-01, regularization 5.82e-01
# Lambda = 1.41e+00, selected 20 features in 10 epochs
# val_objective 9.69e-01, val_loss 1.51e-01, regularization 5.80e-01
# Lambda = 1.42e+00, selected 20 features in 10 epochs
# val_objective 9.75e-01, val_loss 1.51e-01, regularization 5.79e-01
# Lambda = 1.44e+00, selected 20 features in 10 epochs
# val_objective 9.82e-01, val_loss 1.51e-01, regularization 5.78e-01
# Lambda = 1.45e+00, selected 20 features in 10 epochs
# val_objective 9.88e-01, val_loss 1.52e-01, regularization 5.77e-01
# Lambda = 1.47e+00, selected 20 features in 10 epochs
# val_objective 9.95e-01, val_loss 1.52e-01, regularization 5.75e-01
# Lambda = 1.48e+00, selected 20 features in 10 epochs
# val_objective 1.00e+00, val_loss 1.52e-01, regularization 5.74e-01
# Lambda = 1.50e+00, selected 20 features in 10 epochs
# val_objective 1.01e+00, val_loss 1.52e-01, regularization 5.73e-01
# Lambda = 1.51e+00, selected 20 features in 10 epochs
# val_objective 1.01e+00, val_loss 1.52e-01, regularization 5.72e-01
# Lambda = 1.53e+00, selected 20 features in 10 epochs
# val_objective 1.02e+00, val_loss 1.52e-01, regularization 5.70e-01
# Lambda = 1.54e+00, selected 20 features in 10 epochs
# val_objective 1.03e+00, val_loss 1.52e-01, regularization 5.69e-01
# Lambda = 1.56e+00, selected 20 features in 10 epochs
# val_objective 1.04e+00, val_loss 1.52e-01, regularization 5.68e-01
# Lambda = 1.57e+00, selected 20 features in 10 epochs
# val_objective 1.04e+00, val_loss 1.52e-01, regularization 5.66e-01
# Lambda = 1.59e+00, selected 20 features in 10 epochs
# val_objective 1.05e+00, val_loss 1.52e-01, regularization 5.65e-01
# Lambda = 1.60e+00, selected 20 features in 10 epochs
# val_objective 1.06e+00, val_loss 1.52e-01, regularization 5.64e-01
# Lambda = 1.62e+00, selected 20 features in 10 epochs
# val_objective 1.06e+00, val_loss 1.52e-01, regularization 5.63e-01
# Lambda = 1.64e+00, selected 20 features in 10 epochs
# val_objective 1.07e+00, val_loss 1.52e-01, regularization 5.61e-01
# Lambda = 1.65e+00, selected 20 features in 10 epochs
# val_objective 1.08e+00, val_loss 1.52e-01, regularization 5.60e-01
# Lambda = 1.67e+00, selected 20 features in 10 epochs
# val_objective 1.08e+00, val_loss 1.52e-01, regularization 5.59e-01
# Lambda = 1.69e+00, selected 20 features in 10 epochs
# val_objective 1.09e+00, val_loss 1.52e-01, regularization 5.58e-01
# Lambda = 1.70e+00, selected 20 features in 10 epochs
# val_objective 1.10e+00, val_loss 1.52e-01, regularization 5.56e-01
# Lambda = 1.72e+00, selected 20 features in 10 epochs
# val_objective 1.11e+00, val_loss 1.52e-01, regularization 5.55e-01
# Lambda = 1.74e+00, selected 20 features in 10 epochs
# val_objective 1.11e+00, val_loss 1.52e-01, regularization 5.54e-01
# Lambda = 1.75e+00, selected 20 features in 10 epochs
# val_objective 1.12e+00, val_loss 1.52e-01, regularization 5.52e-01
# Lambda = 1.77e+00, selected 20 features in 10 epochs
# val_objective 1.13e+00, val_loss 1.52e-01, regularization 5.51e-01
# Lambda = 1.79e+00, selected 20 features in 10 epochs
# val_objective 1.13e+00, val_loss 1.52e-01, regularization 5.50e-01
# Lambda = 1.81e+00, selected 20 features in 10 epochs
# val_objective 1.14e+00, val_loss 1.52e-01, regularization 5.48e-01
# Lambda = 1.82e+00, selected 20 features in 10 epochs
# val_objective 1.15e+00, val_loss 1.52e-01, regularization 5.47e-01
# Lambda = 1.84e+00, selected 20 features in 10 epochs
# val_objective 1.16e+00, val_loss 1.52e-01, regularization 5.45e-01
# Lambda = 1.86e+00, selected 20 features in 10 epochs
# val_objective 1.16e+00, val_loss 1.52e-01, regularization 5.44e-01
# Lambda = 1.88e+00, selected 20 features in 10 epochs
# val_objective 1.17e+00, val_loss 1.52e-01, regularization 5.43e-01
# Lambda = 1.90e+00, selected 20 features in 10 epochs
# val_objective 1.18e+00, val_loss 1.52e-01, regularization 5.41e-01
# Lambda = 1.92e+00, selected 20 features in 10 epochs
# val_objective 1.19e+00, val_loss 1.52e-01, regularization 5.40e-01
# Lambda = 1.94e+00, selected 20 features in 10 epochs
# val_objective 1.19e+00, val_loss 1.52e-01, regularization 5.38e-01
# Lambda = 1.96e+00, selected 20 features in 10 epochs
# val_objective 1.20e+00, val_loss 1.52e-01, regularization 5.37e-01
# Lambda = 1.98e+00, selected 20 features in 10 epochs
# val_objective 1.21e+00, val_loss 1.52e-01, regularization 5.35e-01
# Lambda = 2.00e+00, selected 20 features in 10 epochs
# val_objective 1.22e+00, val_loss 1.52e-01, regularization 5.33e-01
# Lambda = 2.02e+00, selected 20 features in 10 epochs
# val_objective 1.22e+00, val_loss 1.52e-01, regularization 5.32e-01
# Lambda = 2.04e+00, selected 20 features in 10 epochs
# val_objective 1.23e+00, val_loss 1.52e-01, regularization 5.30e-01
# Lambda = 2.06e+00, selected 20 features in 10 epochs
# val_objective 1.24e+00, val_loss 1.52e-01, regularization 5.29e-01
# Lambda = 2.08e+00, selected 20 features in 10 epochs
# val_objective 1.25e+00, val_loss 1.52e-01, regularization 5.27e-01
# Lambda = 2.10e+00, selected 20 features in 10 epochs
# val_objective 1.25e+00, val_loss 1.52e-01, regularization 5.25e-01
# Lambda = 2.12e+00, selected 20 features in 10 epochs
# val_objective 1.26e+00, val_loss 1.52e-01, regularization 5.24e-01
# Lambda = 2.14e+00, selected 20 features in 10 epochs
# val_objective 1.27e+00, val_loss 1.52e-01, regularization 5.22e-01
# Lambda = 2.16e+00, selected 20 features in 10 epochs
# val_objective 1.28e+00, val_loss 1.52e-01, regularization 5.20e-01
# Lambda = 2.18e+00, selected 20 features in 10 epochs
# val_objective 1.28e+00, val_loss 1.52e-01, regularization 5.19e-01
# Lambda = 2.20e+00, selected 20 features in 10 epochs
# val_objective 1.29e+00, val_loss 1.52e-01, regularization 5.17e-01
# Lambda = 2.23e+00, selected 20 features in 10 epochs
# val_objective 1.30e+00, val_loss 1.52e-01, regularization 5.15e-01
# Lambda = 2.25e+00, selected 20 features in 10 epochs
# val_objective 1.31e+00, val_loss 1.52e-01, regularization 5.14e-01
# Lambda = 2.27e+00, selected 20 features in 10 epochs
# val_objective 1.31e+00, val_loss 1.52e-01, regularization 5.12e-01
# Lambda = 2.29e+00, selected 20 features in 10 epochs
# val_objective 1.32e+00, val_loss 1.52e-01, regularization 5.10e-01
# Lambda = 2.32e+00, selected 20 features in 10 epochs
# val_objective 1.33e+00, val_loss 1.52e-01, regularization 5.09e-01
# Lambda = 2.34e+00, selected 20 features in 10 epochs
# val_objective 1.34e+00, val_loss 1.52e-01, regularization 5.07e-01
# Lambda = 2.36e+00, selected 20 features in 10 epochs
# val_objective 1.35e+00, val_loss 1.52e-01, regularization 5.05e-01
# Lambda = 2.39e+00, selected 20 features in 10 epochs
# val_objective 1.35e+00, val_loss 1.52e-01, regularization 5.04e-01
# Lambda = 2.41e+00, selected 20 features in 10 epochs
# val_objective 1.36e+00, val_loss 1.52e-01, regularization 5.02e-01
# Lambda = 2.43e+00, selected 20 features in 10 epochs
# val_objective 1.37e+00, val_loss 1.52e-01, regularization 5.00e-01
# Lambda = 2.46e+00, selected 20 features in 10 epochs
# val_objective 1.38e+00, val_loss 1.52e-01, regularization 4.98e-01
# Lambda = 2.48e+00, selected 20 features in 10 epochs
# val_objective 1.39e+00, val_loss 1.51e-01, regularization 4.97e-01
# Lambda = 2.51e+00, selected 20 features in 10 epochs
# val_objective 1.39e+00, val_loss 1.51e-01, regularization 4.95e-01
# Lambda = 2.53e+00, selected 20 features in 10 epochs
# val_objective 1.40e+00, val_loss 1.51e-01, regularization 4.93e-01
# Lambda = 2.56e+00, selected 20 features in 10 epochs
# val_objective 1.41e+00, val_loss 1.51e-01, regularization 4.91e-01
# Lambda = 2.58e+00, selected 20 features in 10 epochs
# val_objective 1.42e+00, val_loss 1.51e-01, regularization 4.89e-01
# Lambda = 2.61e+00, selected 20 features in 10 epochs
# val_objective 1.42e+00, val_loss 1.51e-01, regularization 4.88e-01
# Lambda = 2.64e+00, selected 20 features in 10 epochs
# val_objective 1.43e+00, val_loss 1.51e-01, regularization 4.86e-01
# Lambda = 2.66e+00, selected 20 features in 10 epochs
# val_objective 1.44e+00, val_loss 1.51e-01, regularization 4.84e-01
# Lambda = 2.69e+00, selected 20 features in 10 epochs
# val_objective 1.45e+00, val_loss 1.51e-01, regularization 4.82e-01
# Lambda = 2.72e+00, selected 20 features in 10 epochs
# val_objective 1.45e+00, val_loss 1.51e-01, regularization 4.80e-01
# Lambda = 2.74e+00, selected 20 features in 10 epochs
# val_objective 1.46e+00, val_loss 1.51e-01, regularization 4.78e-01
# Lambda = 2.77e+00, selected 20 features in 10 epochs
# val_objective 1.47e+00, val_loss 1.51e-01, regularization 4.76e-01
# Lambda = 2.80e+00, selected 20 features in 10 epochs
# val_objective 1.48e+00, val_loss 1.51e-01, regularization 4.74e-01
# Lambda = 2.83e+00, selected 20 features in 10 epochs
# val_objective 1.49e+00, val_loss 1.50e-01, regularization 4.72e-01
# Lambda = 2.86e+00, selected 20 features in 10 epochs
# val_objective 1.49e+00, val_loss 1.50e-01, regularization 4.70e-01
# Lambda = 2.88e+00, selected 20 features in 10 epochs
# val_objective 1.50e+00, val_loss 1.50e-01, regularization 4.68e-01
# Lambda = 2.91e+00, selected 20 features in 10 epochs
# val_objective 1.51e+00, val_loss 1.50e-01, regularization 4.66e-01
# Lambda = 2.94e+00, selected 20 features in 10 epochs
# val_objective 1.52e+00, val_loss 1.50e-01, regularization 4.64e-01
# Lambda = 2.97e+00, selected 20 features in 10 epochs
# val_objective 1.52e+00, val_loss 1.50e-01, regularization 4.62e-01
# Lambda = 3.00e+00, selected 20 features in 10 epochs
# val_objective 1.53e+00, val_loss 1.50e-01, regularization 4.60e-01
# Lambda = 3.03e+00, selected 20 features in 10 epochs
# val_objective 1.54e+00, val_loss 1.50e-01, regularization 4.58e-01
# Lambda = 3.06e+00, selected 20 features in 10 epochs
# val_objective 1.55e+00, val_loss 1.49e-01, regularization 4.56e-01
# Lambda = 3.09e+00, selected 20 features in 10 epochs
# val_objective 1.55e+00, val_loss 1.49e-01, regularization 4.54e-01
# Lambda = 3.12e+00, selected 20 features in 10 epochs
# val_objective 1.56e+00, val_loss 1.49e-01, regularization 4.52e-01
# Lambda = 3.15e+00, selected 20 features in 10 epochs
# val_objective 1.57e+00, val_loss 1.49e-01, regularization 4.50e-01
# Lambda = 3.19e+00, selected 20 features in 10 epochs
# val_objective 1.58e+00, val_loss 1.49e-01, regularization 4.48e-01
# Lambda = 3.22e+00, selected 20 features in 10 epochs
# val_objective 1.58e+00, val_loss 1.49e-01, regularization 4.46e-01
# Lambda = 3.25e+00, selected 20 features in 10 epochs
# val_objective 1.59e+00, val_loss 1.48e-01, regularization 4.44e-01
# Lambda = 3.28e+00, selected 20 features in 10 epochs
# val_objective 1.60e+00, val_loss 1.48e-01, regularization 4.42e-01
# Lambda = 3.31e+00, selected 20 features in 10 epochs
# val_objective 1.61e+00, val_loss 1.48e-01, regularization 4.40e-01
# Lambda = 3.35e+00, selected 20 features in 10 epochs
# val_objective 1.61e+00, val_loss 1.48e-01, regularization 4.38e-01
# Lambda = 3.38e+00, selected 20 features in 10 epochs
# val_objective 1.62e+00, val_loss 1.48e-01, regularization 4.36e-01
# Lambda = 3.42e+00, selected 20 features in 10 epochs
# val_objective 1.63e+00, val_loss 1.48e-01, regularization 4.34e-01
# Lambda = 3.45e+00, selected 20 features in 10 epochs
# val_objective 1.64e+00, val_loss 1.48e-01, regularization 4.32e-01
# Lambda = 3.48e+00, selected 20 features in 10 epochs
# val_objective 1.65e+00, val_loss 1.47e-01, regularization 4.30e-01
# Lambda = 3.52e+00, selected 20 features in 10 epochs
# val_objective 1.65e+00, val_loss 1.47e-01, regularization 4.28e-01
# Lambda = 3.55e+00, selected 20 features in 10 epochs
# val_objective 1.66e+00, val_loss 1.47e-01, regularization 4.26e-01
# Lambda = 3.59e+00, selected 20 features in 10 epochs
# val_objective 1.67e+00, val_loss 1.47e-01, regularization 4.24e-01
# Lambda = 3.63e+00, selected 20 features in 10 epochs
# val_objective 1.68e+00, val_loss 1.47e-01, regularization 4.22e-01
# Lambda = 3.66e+00, selected 20 features in 10 epochs
# val_objective 1.69e+00, val_loss 1.47e-01, regularization 4.20e-01
# Lambda = 3.70e+00, selected 20 features in 10 epochs
# val_objective 1.69e+00, val_loss 1.46e-01, regularization 4.18e-01
# Lambda = 3.74e+00, selected 20 features in 10 epochs
# val_objective 1.70e+00, val_loss 1.46e-01, regularization 4.16e-01
# Lambda = 3.77e+00, selected 20 features in 10 epochs
# val_objective 1.71e+00, val_loss 1.46e-01, regularization 4.14e-01
# Lambda = 3.81e+00, selected 20 features in 10 epochs
# val_objective 1.72e+00, val_loss 1.46e-01, regularization 4.12e-01
# Lambda = 3.85e+00, selected 20 features in 10 epochs
# val_objective 1.73e+00, val_loss 1.46e-01, regularization 4.10e-01
# Lambda = 3.89e+00, selected 20 features in 10 epochs
# val_objective 1.73e+00, val_loss 1.46e-01, regularization 4.08e-01
# Lambda = 3.93e+00, selected 20 features in 10 epochs
# val_objective 1.74e+00, val_loss 1.46e-01, regularization 4.06e-01
# Lambda = 3.96e+00, selected 20 features in 10 epochs
# val_objective 1.75e+00, val_loss 1.46e-01, regularization 4.04e-01
# Lambda = 4.00e+00, selected 20 features in 10 epochs
# val_objective 1.76e+00, val_loss 1.46e-01, regularization 4.03e-01
# Lambda = 4.04e+00, selected 20 features in 10 epochs
# val_objective 1.77e+00, val_loss 1.46e-01, regularization 4.01e-01
# Lambda = 4.09e+00, selected 20 features in 10 epochs
# val_objective 1.77e+00, val_loss 1.45e-01, regularization 3.99e-01
# Lambda = 4.13e+00, selected 20 features in 10 epochs
# val_objective 1.78e+00, val_loss 1.45e-01, regularization 3.97e-01
# Lambda = 4.17e+00, selected 20 features in 10 epochs
# val_objective 1.79e+00, val_loss 1.45e-01, regularization 3.95e-01
# Lambda = 4.21e+00, selected 20 features in 10 epochs
# val_objective 1.80e+00, val_loss 1.45e-01, regularization 3.93e-01
# Lambda = 4.25e+00, selected 20 features in 10 epochs
# val_objective 1.81e+00, val_loss 1.45e-01, regularization 3.91e-01
# Lambda = 4.29e+00, selected 20 features in 10 epochs
# val_objective 1.81e+00, val_loss 1.45e-01, regularization 3.89e-01
# Lambda = 4.34e+00, selected 20 features in 10 epochs
# val_objective 1.82e+00, val_loss 1.45e-01, regularization 3.87e-01
# Lambda = 4.38e+00, selected 20 features in 10 epochs
# val_objective 1.83e+00, val_loss 1.45e-01, regularization 3.85e-01
# Lambda = 4.42e+00, selected 20 features in 10 epochs
# val_objective 1.84e+00, val_loss 1.45e-01, regularization 3.83e-01
# Lambda = 4.47e+00, selected 20 features in 10 epochs
# val_objective 1.85e+00, val_loss 1.45e-01, regularization 3.81e-01
# Lambda = 4.51e+00, selected 20 features in 10 epochs
# val_objective 1.85e+00, val_loss 1.45e-01, regularization 3.79e-01
# Lambda = 4.56e+00, selected 20 features in 10 epochs
# val_objective 1.86e+00, val_loss 1.45e-01, regularization 3.76e-01
# Lambda = 4.60e+00, selected 20 features in 10 epochs
# val_objective 1.87e+00, val_loss 1.45e-01, regularization 3.74e-01
# Lambda = 4.65e+00, selected 20 features in 10 epochs
# val_objective 1.88e+00, val_loss 1.45e-01, regularization 3.72e-01
# Lambda = 4.70e+00, selected 20 features in 10 epochs
# val_objective 1.88e+00, val_loss 1.45e-01, regularization 3.70e-01
# Lambda = 4.74e+00, selected 20 features in 10 epochs
# val_objective 1.89e+00, val_loss 1.45e-01, regularization 3.68e-01
# Lambda = 4.79e+00, selected 20 features in 10 epochs
# val_objective 1.90e+00, val_loss 1.45e-01, regularization 3.66e-01
# Lambda = 4.84e+00, selected 20 features in 10 epochs
# val_objective 1.90e+00, val_loss 1.44e-01, regularization 3.64e-01
# Lambda = 4.89e+00, selected 20 features in 10 epochs
# val_objective 1.91e+00, val_loss 1.44e-01, regularization 3.62e-01
# Lambda = 4.94e+00, selected 20 features in 10 epochs
# val_objective 1.92e+00, val_loss 1.44e-01, regularization 3.60e-01
# Lambda = 4.98e+00, selected 20 features in 10 epochs
# val_objective 1.93e+00, val_loss 1.44e-01, regularization 3.57e-01
# Lambda = 5.03e+00, selected 20 features in 10 epochs
# val_objective 1.93e+00, val_loss 1.44e-01, regularization 3.55e-01
# Lambda = 5.08e+00, selected 20 features in 10 epochs
# val_objective 1.94e+00, val_loss 1.44e-01, regularization 3.53e-01
# Lambda = 5.14e+00, selected 20 features in 10 epochs
# val_objective 1.95e+00, val_loss 1.44e-01, regularization 3.51e-01
# Lambda = 5.19e+00, selected 20 features in 10 epochs
# val_objective 1.95e+00, val_loss 1.44e-01, regularization 3.49e-01
# Lambda = 5.24e+00, selected 20 features in 10 epochs
# val_objective 1.96e+00, val_loss 1.43e-01, regularization 3.46e-01
# Lambda = 5.29e+00, selected 20 features in 10 epochs
# val_objective 1.96e+00, val_loss 1.43e-01, regularization 3.44e-01
# Lambda = 5.34e+00, selected 20 features in 10 epochs
# val_objective 1.97e+00, val_loss 1.43e-01, regularization 3.42e-01
# Lambda = 5.40e+00, selected 20 features in 10 epochs
# val_objective 1.98e+00, val_loss 1.43e-01, regularization 3.40e-01
# Lambda = 5.45e+00, selected 20 features in 10 epochs
# val_objective 1.98e+00, val_loss 1.43e-01, regularization 3.37e-01
# Lambda = 5.51e+00, selected 20 features in 10 epochs
# val_objective 1.99e+00, val_loss 1.43e-01, regularization 3.35e-01
# Lambda = 5.56e+00, selected 20 features in 10 epochs
# val_objective 1.99e+00, val_loss 1.43e-01, regularization 3.33e-01
# Lambda = 5.62e+00, selected 20 features in 10 epochs
# val_objective 2.00e+00, val_loss 1.43e-01, regularization 3.30e-01
# Lambda = 5.67e+00, selected 20 features in 10 epochs
# val_objective 2.00e+00, val_loss 1.43e-01, regularization 3.28e-01
# Lambda = 5.73e+00, selected 20 features in 10 epochs
# val_objective 2.01e+00, val_loss 1.43e-01, regularization 3.26e-01
# Lambda = 5.79e+00, selected 20 features in 10 epochs
# val_objective 2.01e+00, val_loss 1.43e-01, regularization 3.23e-01
# Lambda = 5.84e+00, selected 20 features in 10 epochs
# val_objective 2.02e+00, val_loss 1.43e-01, regularization 3.21e-01
# Lambda = 5.90e+00, selected 20 features in 10 epochs
# val_objective 2.02e+00, val_loss 1.43e-01, regularization 3.19e-01
# Lambda = 5.96e+00, selected 20 features in 10 epochs
# val_objective 2.03e+00, val_loss 1.43e-01, regularization 3.16e-01
# Lambda = 6.02e+00, selected 20 features in 10 epochs
# val_objective 2.03e+00, val_loss 1.43e-01, regularization 3.14e-01
# Lambda = 6.08e+00, selected 20 features in 10 epochs
# val_objective 2.04e+00, val_loss 1.43e-01, regularization 3.11e-01
# Lambda = 6.14e+00, selected 20 features in 10 epochs
# val_objective 2.04e+00, val_loss 1.43e-01, regularization 3.09e-01
# Lambda = 6.20e+00, selected 20 features in 10 epochs
# val_objective 2.04e+00, val_loss 1.43e-01, regularization 3.06e-01
# Lambda = 6.27e+00, selected 20 features in 10 epochs
# val_objective 2.05e+00, val_loss 1.43e-01, regularization 3.04e-01
# Lambda = 6.33e+00, selected 20 features in 10 epochs
# val_objective 2.05e+00, val_loss 1.43e-01, regularization 3.01e-01
# Lambda = 6.39e+00, selected 20 features in 10 epochs
# val_objective 2.05e+00, val_loss 1.43e-01, regularization 2.99e-01
# Lambda = 6.46e+00, selected 20 features in 10 epochs
# val_objective 2.06e+00, val_loss 1.43e-01, regularization 2.96e-01
# Lambda = 6.52e+00, selected 20 features in 10 epochs
# val_objective 2.06e+00, val_loss 1.43e-01, regularization 2.94e-01
# Lambda = 6.59e+00, selected 20 features in 10 epochs
# val_objective 2.06e+00, val_loss 1.43e-01, regularization 2.91e-01
# Lambda = 6.65e+00, selected 20 features in 10 epochs
# val_objective 2.06e+00, val_loss 1.43e-01, regularization 2.89e-01
# Lambda = 6.72e+00, selected 20 features in 10 epochs
# val_objective 2.07e+00, val_loss 1.43e-01, regularization 2.86e-01
# Lambda = 6.79e+00, selected 20 features in 10 epochs
# val_objective 2.07e+00, val_loss 1.43e-01, regularization 2.84e-01
# Lambda = 6.85e+00, selected 20 features in 10 epochs
# val_objective 2.07e+00, val_loss 1.42e-01, regularization 2.81e-01
# Lambda = 6.92e+00, selected 20 features in 10 epochs
# val_objective 2.07e+00, val_loss 1.42e-01, regularization 2.79e-01
# Lambda = 6.99e+00, selected 20 features in 10 epochs
# val_objective 2.07e+00, val_loss 1.42e-01, regularization 2.76e-01
# Lambda = 7.06e+00, selected 20 features in 10 epochs
# val_objective 2.08e+00, val_loss 1.42e-01, regularization 2.74e-01
# Lambda = 7.13e+00, selected 20 features in 10 epochs
# val_objective 2.08e+00, val_loss 1.42e-01, regularization 2.71e-01
# Lambda = 7.20e+00, selected 20 features in 10 epochs
# val_objective 2.08e+00, val_loss 1.42e-01, regularization 2.69e-01
# Lambda = 7.28e+00, selected 20 features in 10 epochs
# val_objective 2.08e+00, val_loss 1.42e-01, regularization 2.66e-01
# Lambda = 7.35e+00, selected 20 features in 10 epochs
# val_objective 2.08e+00, val_loss 1.42e-01, regularization 2.64e-01
# Lambda = 7.42e+00, selected 20 features in 10 epochs
# val_objective 2.08e+00, val_loss 1.41e-01, regularization 2.61e-01
# Lambda = 7.50e+00, selected 20 features in 10 epochs
# val_objective 2.08e+00, val_loss 1.41e-01, regularization 2.59e-01
# Lambda = 7.57e+00, selected 20 features in 10 epochs
# val_objective 2.08e+00, val_loss 1.41e-01, regularization 2.56e-01
# Lambda = 7.65e+00, selected 20 features in 10 epochs
# val_objective 2.08e+00, val_loss 1.41e-01, regularization 2.53e-01
# Lambda = 7.72e+00, selected 20 features in 10 epochs
# val_objective 2.08e+00, val_loss 1.40e-01, regularization 2.51e-01
# Lambda = 7.80e+00, selected 20 features in 10 epochs
# val_objective 2.08e+00, val_loss 1.40e-01, regularization 2.48e-01
# Lambda = 7.88e+00, selected 20 features in 10 epochs
# val_objective 2.07e+00, val_loss 1.40e-01, regularization 2.46e-01
# Lambda = 7.96e+00, selected 20 features in 20 epochs
# val_objective 2.05e+00, val_loss 1.39e-01, regularization 2.40e-01
# Lambda = 8.04e+00, selected 20 features in 10 epochs
# val_objective 2.05e+00, val_loss 1.39e-01, regularization 2.38e-01
# Lambda = 8.12e+00, selected 20 features in 10 epochs
# val_objective 2.05e+00, val_loss 1.39e-01, regularization 2.35e-01
# Lambda = 8.20e+00, selected 20 features in 10 epochs
# val_objective 2.05e+00, val_loss 1.39e-01, regularization 2.33e-01
# Lambda = 8.28e+00, selected 20 features in 10 epochs
# val_objective 2.05e+00, val_loss 1.39e-01, regularization 2.31e-01
# Lambda = 8.36e+00, selected 20 features in 10 epochs
# val_objective 2.05e+00, val_loss 1.39e-01, regularization 2.28e-01
# Lambda = 8.45e+00, selected 20 features in 10 epochs
# val_objective 2.05e+00, val_loss 1.39e-01, regularization 2.26e-01
# Lambda = 8.53e+00, selected 20 features in 10 epochs
# val_objective 2.05e+00, val_loss 1.39e-01, regularization 2.24e-01
# ...
# Lambda = 3.47e+03, selected 4 features in 11 epochs
# val_objective 3.90e+00, val_loss 3.60e-01, regularization 1.02e-03
# Lambda = 3.51e+03, selected 4 features in 11 epochs
# val_objective 3.91e+00, val_loss 3.61e-01, regularization 1.01e-03
# Lambda = 3.54e+03, selected 4 features in 11 epochs
# val_objective 3.92e+00, val_loss 3.64e-01, regularization 1.00e-03
# Lambda = 3.58e+03, selected 4 features in 11 epochs
# val_objective 3.91e+00, val_loss 3.66e-01, regularization 9.92e-04
# Lambda = 3.61e+03, selected 4 features in 11 epochs
# val_objective 3.93e+00, val_loss 3.67e-01, regularization 9.87e-04
# Lambda = 3.65e+03, selected 4 features in 11 epochs
# val_objective 3.94e+00, val_loss 3.68e-01, regularization 9.80e-04
# Lambda = 3.69e+03, selected 4 features in 11 epochs
# val_objective 3.94e+00, val_loss 3.71e-01, regularization 9.68e-04
# Lambda = 3.72e+03, selected 4 features in 11 epochs
# val_objective 3.96e+00, val_loss 3.71e-01, regularization 9.65e-04
# Lambda = 3.76e+03, selected 4 features in 11 epochs
# val_objective 3.96e+00, val_loss 3.74e-01, regularization 9.53e-04
# Lambda = 3.80e+03, selected 4 features in 11 epochs
# val_objective 3.97e+00, val_loss 3.75e-01, regularization 9.46e-04
# Lambda = 3.84e+03, selected 4 features in 11 epochs
# val_objective 3.92e+00, val_loss 3.81e-01, regularization 9.23e-04
# Lambda = 3.87e+03, selected 4 features in 11 epochs
# val_objective 3.97e+00, val_loss 3.80e-01, regularization 9.26e-04
# Lambda = 3.91e+03, selected 4 features in 11 epochs
# val_objective 3.98e+00, val_loss 3.81e-01, regularization 9.19e-04
# Lambda = 3.95e+03, selected 4 features in 11 epochs
# val_objective 3.97e+00, val_loss 3.84e-01, regularization 9.08e-04
# Lambda = 3.99e+03, selected 4 features in 11 epochs
# val_objective 3.93e+00, val_loss 3.90e-01, regularization 8.88e-04
# Lambda = 4.03e+03, selected 4 features in 11 epochs
# val_objective 3.95e+00, val_loss 3.90e-01, regularization 8.84e-04
# Lambda = 4.07e+03, selected 4 features in 11 epochs
# val_objective 3.98e+00, val_loss 3.90e-01, regularization 8.82e-04
# Lambda = 4.11e+03, selected 4 features in 11 epochs
# val_objective 3.98e+00, val_loss 3.93e-01, regularization 8.72e-04
# Lambda = 4.15e+03, selected 4 features in 11 epochs
# val_objective 3.95e+00, val_loss 3.98e-01, regularization 8.54e-04
# Lambda = 4.19e+03, selected 4 features in 11 epochs
# val_objective 3.96e+00, val_loss 4.00e-01, regularization 8.48e-04
# Lambda = 4.24e+03, selected 4 features in 11 epochs
# val_objective 3.99e+00, val_loss 3.99e-01, regularization 8.47e-04
# Lambda = 4.28e+03, selected 4 features in 11 epochs
# val_objective 3.99e+00, val_loss 4.01e-01, regularization 8.40e-04
# Lambda = 4.32e+03, selected 4 features in 11 epochs
# val_objective 3.98e+00, val_loss 4.05e-01, regularization 8.27e-04
# Lambda = 4.37e+03, selected 4 features in 11 epochs
# val_objective 3.98e+00, val_loss 4.07e-01, regularization 8.19e-04
# Lambda = 4.41e+03, selected 4 features in 11 epochs
# val_objective 4.00e+00, val_loss 4.07e-01, regularization 8.16e-04
# Lambda = 4.45e+03, selected 4 features in 11 epochs
# val_objective 4.02e+00, val_loss 4.08e-01, regularization 8.11e-04
# Lambda = 4.50e+03, selected 4 features in 11 epochs
# val_objective 4.03e+00, val_loss 4.10e-01, regularization 8.04e-04
# Lambda = 4.54e+03, selected 4 features in 11 epochs
# val_objective 4.02e+00, val_loss 4.13e-01, regularization 7.94e-04
# Lambda = 4.59e+03, selected 4 features in 11 epochs
# val_objective 4.03e+00, val_loss 4.15e-01, regularization 7.87e-04
# Lambda = 4.63e+03, selected 4 features in 11 epochs
# val_objective 4.04e+00, val_loss 4.16e-01, regularization 7.82e-04
# Lambda = 4.68e+03, selected 4 features in 11 epochs
# val_objective 4.05e+00, val_loss 4.18e-01, regularization 7.76e-04
# Lambda = 4.73e+03, selected 4 features in 11 epochs
# val_objective 4.05e+00, val_loss 4.21e-01, regularization 7.68e-04
# Lambda = 4.77e+03, selected 4 features in 11 epochs
# val_objective 4.05e+00, val_loss 4.23e-01, regularization 7.61e-04
# Lambda = 4.82e+03, selected 4 features in 11 epochs
# val_objective 4.07e+00, val_loss 4.23e-01, regularization 7.57e-04
# Lambda = 4.87e+03, selected 4 features in 11 epochs
# val_objective 4.09e+00, val_loss 4.24e-01, regularization 7.54e-04
# Lambda = 4.92e+03, selected 4 features in 11 epochs
# val_objective 4.10e+00, val_loss 4.26e-01, regularization 7.47e-04
# Lambda = 4.97e+03, selected 4 features in 11 epochs
# val_objective 4.11e+00, val_loss 4.27e-01, regularization 7.42e-04
# Lambda = 5.02e+03, selected 4 features in 11 epochs
# val_objective 4.13e+00, val_loss 4.28e-01, regularization 7.38e-04
# Lambda = 5.07e+03, selected 4 features in 11 epochs
# val_objective 4.16e+00, val_loss 4.28e-01, regularization 7.36e-04
# Lambda = 5.12e+03, selected 4 features in 11 epochs
# val_objective 4.17e+00, val_loss 4.30e-01, regularization 7.30e-04
# Lambda = 5.17e+03, selected 4 features in 11 epochs
# val_objective 4.16e+00, val_loss 4.33e-01, regularization 7.22e-04
# Lambda = 5.22e+03, selected 4 features in 11 epochs
# val_objective 4.15e+00, val_loss 4.36e-01, regularization 7.12e-04
# Lambda = 5.27e+03, selected 4 features in 11 epochs
# val_objective 4.16e+00, val_loss 4.38e-01, regularization 7.07e-04
# Lambda = 5.33e+03, selected 4 features in 11 epochs
# val_objective 4.17e+00, val_loss 4.40e-01, regularization 7.00e-04
# Lambda = 5.38e+03, selected 4 features in 11 epochs
# val_objective 4.16e+00, val_loss 4.43e-01, regularization 6.91e-04
# Lambda = 5.43e+03, selected 4 features in 11 epochs
# val_objective 4.15e+00, val_loss 4.47e-01, regularization 6.82e-04
# Lambda = 5.49e+03, selected 4 features in 11 epochs
# val_objective 4.14e+00, val_loss 4.51e-01, regularization 6.72e-04
# Lambda = 5.54e+03, selected 4 features in 11 epochs
# val_objective 4.11e+00, val_loss 4.56e-01, regularization 6.58e-04
# Lambda = 5.60e+03, selected 4 features in 11 epochs
# val_objective 4.06e+00, val_loss 4.62e-01, regularization 6.43e-04
# Lambda = 5.65e+03, selected 4 features in 11 epochs
# val_objective 4.08e+00, val_loss 4.64e-01, regularization 6.39e-04
# Lambda = 5.71e+03, selected 4 features in 11 epochs
# val_objective 4.08e+00, val_loss 4.67e-01, regularization 6.32e-04
# Lambda = 5.77e+03, selected 4 features in 11 epochs
# val_objective 4.05e+00, val_loss 4.73e-01, regularization 6.20e-04
# Lambda = 5.83e+03, selected 4 features in 11 epochs
# val_objective 4.02e+00, val_loss 4.78e-01, regularization 6.07e-04
# Lambda = 5.88e+03, selected 4 features in 11 epochs
# val_objective 4.06e+00, val_loss 4.75e-01, regularization 6.09e-04
# Lambda = 5.94e+03, selected 3 features in 11 epochs
# val_objective 4.05e+00, val_loss 4.79e-01, regularization 6.01e-04
# Lambda = 6.00e+03, selected 4 features in 11 epochs
# val_objective 4.06e+00, val_loss 4.80e-01, regularization 5.97e-04
# Lambda = 6.06e+03, selected 3 features in 11 epochs
# val_objective 4.08e+00, val_loss 4.81e-01, regularization 5.94e-04
# Lambda = 6.12e+03, selected 3 features in 11 epochs
# val_objective 4.10e+00, val_loss 4.82e-01, regularization 5.91e-04
# Lambda = 6.18e+03, selected 3 features in 11 epochs
# val_objective 4.11e+00, val_loss 4.83e-01, regularization 5.87e-04
# Lambda = 6.25e+03, selected 3 features in 11 epochs
# val_objective 4.10e+00, val_loss 4.87e-01, regularization 5.78e-04
# Lambda = 6.31e+03, selected 3 features in 11 epochs
# val_objective 4.07e+00, val_loss 4.91e-01, regularization 5.67e-04
# Lambda = 6.37e+03, selected 3 features in 11 epochs
# val_objective 4.07e+00, val_loss 4.93e-01, regularization 5.61e-04
# Lambda = 6.43e+03, selected 3 features in 11 epochs
# val_objective 4.04e+00, val_loss 4.97e-01, regularization 5.51e-04
# Lambda = 6.50e+03, selected 3 features in 11 epochs
# val_objective 3.99e+00, val_loss 5.03e-01, regularization 5.36e-04
# Lambda = 6.56e+03, selected 3 features in 11 epochs
# val_objective 3.92e+00, val_loss 5.11e-01, regularization 5.19e-04
# Lambda = 6.63e+03, selected 3 features in 11 epochs
# val_objective 3.86e+00, val_loss 5.18e-01, regularization 5.04e-04
# Lambda = 6.70e+03, selected 3 features in 11 epochs
# val_objective 3.79e+00, val_loss 5.26e-01, regularization 4.88e-04
# Lambda = 6.76e+03, selected 3 features in 11 epochs
# val_objective 3.72e+00, val_loss 5.35e-01, regularization 4.71e-04
# Lambda = 6.83e+03, selected 3 features in 11 epochs
# val_objective 3.63e+00, val_loss 5.45e-01, regularization 4.52e-04
# Lambda = 6.90e+03, selected 3 features in 11 epochs
# val_objective 3.53e+00, val_loss 5.57e-01, regularization 4.30e-04
# Lambda = 6.97e+03, selected 3 features in 11 epochs
# val_objective 3.43e+00, val_loss 5.67e-01, regularization 4.11e-04
# Lambda = 7.04e+03, selected 3 features in 11 epochs
# val_objective 3.33e+00, val_loss 5.78e-01, regularization 3.92e-04
# Lambda = 7.11e+03, selected 3 features in 11 epochs
# val_objective 3.24e+00, val_loss 5.89e-01, regularization 3.73e-04
# Lambda = 7.18e+03, selected 3 features in 11 epochs
# val_objective 3.14e+00, val_loss 5.99e-01, regularization 3.54e-04
# Lambda = 7.25e+03, selected 3 features in 11 epochs
# val_objective 3.02e+00, val_loss 6.12e-01, regularization 3.32e-04
# Lambda = 7.32e+03, selected 3 features in 11 epochs
# val_objective 2.92e+00, val_loss 6.24e-01, regularization 3.13e-04
# Lambda = 7.40e+03, selected 3 features in 11 epochs
# val_objective 2.80e+00, val_loss 6.37e-01, regularization 2.92e-04
# Lambda = 7.47e+03, selected 3 features in 11 epochs
# val_objective 2.72e+00, val_loss 6.45e-01, regularization 2.78e-04
# Lambda = 7.55e+03, selected 3 features in 11 epochs
# val_objective 2.63e+00, val_loss 6.55e-01, regularization 2.62e-04
# Lambda = 7.62e+03, selected 3 features in 11 epochs
# val_objective 2.57e+00, val_loss 6.64e-01, regularization 2.50e-04
# Lambda = 7.70e+03, selected 3 features in 11 epochs
# val_objective 2.56e+00, val_loss 6.65e-01, regularization 2.46e-04
# Lambda = 7.77e+03, selected 2 features in 11 epochs
# val_objective 2.41e+00, val_loss 6.82e-01, regularization 2.22e-04
# Lambda = 7.85e+03, selected 2 features in 11 epochs
# val_objective 2.36e+00, val_loss 6.87e-01, regularization 2.13e-04
# Lambda = 7.93e+03, selected 2 features in 11 epochs
# val_objective 2.31e+00, val_loss 6.93e-01, regularization 2.04e-04
# Lambda = 8.01e+03, selected 1 features in 11 epochs
# val_objective 2.26e+00, val_loss 6.98e-01, regularization 1.95e-04
# Lambda = 8.09e+03, selected 1 features in 11 epochs
# val_objective 2.24e+00, val_loss 7.02e-01, regularization 1.90e-04
# Lambda = 8.17e+03, selected 1 features in 11 epochs
# val_objective 2.22e+00, val_loss 7.05e-01, regularization 1.85e-04
# Lambda = 8.25e+03, selected 1 features in 11 epochs
# val_objective 2.21e+00, val_loss 7.07e-01, regularization 1.82e-04
# Lambda = 8.33e+03, selected 1 features in 11 epochs
# val_objective 2.20e+00, val_loss 7.09e-01, regularization 1.78e-04
# Lambda = 8.42e+03, selected 1 features in 11 epochs
# val_objective 2.16e+00, val_loss 7.14e-01, regularization 1.71e-04
# Lambda = 8.50e+03, selected 1 features in 11 epochs
# val_objective 2.11e+00, val_loss 7.20e-01, regularization 1.63e-04
# Lambda = 8.59e+03, selected 1 features in 11 epochs
# val_objective 2.07e+00, val_loss 7.25e-01, regularization 1.56e-04
# Lambda = 8.67e+03, selected 1 features in 11 epochs
# val_objective 2.02e+00, val_loss 7.30e-01, regularization 1.49e-04
# Lambda = 8.76e+03, selected 1 features in 11 epochs
# val_objective 1.98e+00, val_loss 7.36e-01, regularization 1.42e-04
# Lambda = 8.85e+03, selected 1 features in 11 epochs
# val_objective 1.93e+00, val_loss 7.42e-01, regularization 1.34e-04
# Lambda = 8.94e+03, selected 1 features in 11 epochs
# val_objective 1.88e+00, val_loss 7.48e-01, regularization 1.26e-04
# Lambda = 9.03e+03, selected 1 features in 11 epochs
# val_objective 1.83e+00, val_loss 7.54e-01, regularization 1.19e-04
# Lambda = 9.12e+03, selected 1 features in 11 epochs
# val_objective 1.78e+00, val_loss 7.60e-01, regularization 1.12e-04
# Lambda = 9.21e+03, selected 1 features in 11 epochs
# val_objective 1.73e+00, val_loss 7.66e-01, regularization 1.05e-04
# Lambda = 9.30e+03, selected 1 features in 11 epochs
# val_objective 1.68e+00, val_loss 7.72e-01, regularization 9.81e-05
# Lambda = 9.39e+03, selected 1 features in 11 epochs
# val_objective 1.64e+00, val_loss 7.77e-01, regularization 9.16e-05
# Lambda = 9.49e+03, selected 1 features in 11 epochs
# val_objective 1.59e+00, val_loss 7.83e-01, regularization 8.54e-05
# Lambda = 9.58e+03, selected 1 features in 11 epochs
# val_objective 1.55e+00, val_loss 7.89e-01, regularization 7.94e-05
# Lambda = 9.68e+03, selected 1 features in 11 epochs
# val_objective 1.51e+00, val_loss 7.94e-01, regularization 7.36e-05
# Lambda = 9.77e+03, selected 1 features in 11 epochs
# val_objective 1.46e+00, val_loss 7.99e-01, regularization 6.80e-05
# Lambda = 9.87e+03, selected 1 features in 11 epochs
# val_objective 1.42e+00, val_loss 8.05e-01, regularization 6.25e-05
# Lambda = 9.97e+03, selected 1 features in 11 epochs
# val_objective 1.38e+00, val_loss 8.10e-01, regularization 5.72e-05
# Lambda = 1.01e+04, selected 1 features in 11 epochs
# val_objective 1.34e+00, val_loss 8.15e-01, regularization 5.20e-05
# Lambda = 1.02e+04, selected 1 features in 11 epochs
# val_objective 1.30e+00, val_loss 8.19e-01, regularization 4.75e-05
# Lambda = 1.03e+04, selected 1 features in 11 epochs
# val_objective 1.29e+00, val_loss 8.22e-01, regularization 4.53e-05
# Lambda = 1.04e+04, selected 1 features in 11 epochs
# val_objective 1.28e+00, val_loss 8.23e-01, regularization 4.37e-05
# Lambda = 1.05e+04, selected 1 features in 11 epochs
# val_objective 1.27e+00, val_loss 8.24e-01, regularization 4.31e-05
# Lambda = 1.06e+04, selected 1 features in 11 epochs
# val_objective 1.28e+00, val_loss 8.23e-01, regularization 4.34e-05
# Lambda = 1.07e+04, selected 1 features in 11 epochs
# val_objective 1.30e+00, val_loss 8.22e-01, regularization 4.47e-05
# Lambda = 1.08e+04, selected 1 features in 11 epochs
# val_objective 1.33e+00, val_loss 8.20e-01, regularization 4.69e-05
# Lambda = 1.09e+04, selected 1 features in 11 epochs
# val_objective 1.36e+00, val_loss 8.17e-01, regularization 4.99e-05
# Lambda = 1.10e+04, selected 1 features in 11 epochs
# val_objective 1.40e+00, val_loss 8.13e-01, regularization 5.37e-05
# Lambda = 1.11e+04, selected 1 features in 11 epochs
# val_objective 1.46e+00, val_loss 8.08e-01, regularization 5.83e-05
# Lambda = 1.12e+04, selected 1 features in 11 epochs
# val_objective 1.52e+00, val_loss 8.03e-01, regularization 6.36e-05
# Lambda = 1.13e+04, selected 1 features in 11 epochs
# val_objective 1.59e+00, val_loss 7.97e-01, regularization 6.97e-05
# Lambda = 1.15e+04, selected 1 features in 11 epochs
# val_objective 1.73e+00, val_loss 7.85e-01, regularization 8.26e-05
# Lambda = 1.16e+04, selected 1 features in 11 epochs
# val_objective 1.84e+00, val_loss 7.76e-01, regularization 9.23e-05
# Lambda = 1.17e+04, selected 1 features in 11 epochs
# val_objective 1.74e+00, val_loss 7.86e-01, regularization 8.15e-05
# Lambda = 1.18e+04, selected 1 features in 11 epochs
# val_objective 1.69e+00, val_loss 7.91e-01, regularization 7.64e-05
# Lambda = 1.19e+04, selected 1 features in 11 epochs
# val_objective 1.65e+00, val_loss 7.95e-01, regularization 7.21e-05
# Lambda = 1.20e+04, selected 1 features in 11 epochs
# val_objective 1.61e+00, val_loss 7.99e-01, regularization 6.73e-05
# Lambda = 1.22e+04, selected 1 features in 11 epochs
# val_objective 1.57e+00, val_loss 8.04e-01, regularization 6.28e-05
# Lambda = 1.23e+04, selected 1 features in 11 epochs
# val_objective 1.53e+00, val_loss 8.08e-01, regularization 5.85e-05
# Lambda = 1.24e+04, selected 1 features in 11 epochs
# val_objective 1.42e+00, val_loss 8.18e-01, regularization 4.84e-05
# Lambda = 1.25e+04, selected 1 features in 11 epochs
# val_objective 1.30e+00, val_loss 8.29e-01, regularization 3.78e-05
# Lambda = 1.27e+04, selected 1 features in 11 epochs
# val_objective 1.14e+00, val_loss 8.44e-01, regularization 2.32e-05
# Lambda = 1.28e+04, selected 1 features in 11 epochs
# val_objective 9.20e-01, val_loss 8.64e-01, regularization 4.36e-06
# Lambda = 1.29e+04, selected 1 features in 11 epochs
# val_objective 9.61e-01, val_loss 8.61e-01, regularization 7.81e-06
# Lambda = 1.30e+04, selected 0 features in 11 epochs
# val_objective 8.69e-01, val_loss 8.69e-01, regularization 0.00e+00
